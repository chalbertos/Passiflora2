# %%
import pandas

# %%
pandas.__version__
# Out:
# '1.4.4'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sales_data = pd.read_csv('Online_Cars_Sale_Marketplace.csv')

# %%
pd.read_csv('Online_Cars_Sale_Marketplace.csv')
# Out:
#       Year     Make                   Model Used/New    Price  ConsumerRating  \
# 0     2019   Toyota               Sienna SE     Used  $39,998             4.6
# 1     2018     Ford            F-150 Lariat     Used  $49,985             4.8
# 2     2017      RAM            1500 Laramie     Used  $41,860             4.7
# 3     2021    Honda         Accord Sport SE     Used  $28,500             5.0
# 4     2020    Lexus                  RX 350     Used  $49,000             4.8
# ...    ...      ...                     ...      ...      ...             ...
# 9374  2019   Subaru  Crosstrek 2.0i Premium     Used  $27,374             4.7
# 9375  2019     Audi         Q8 3.0T Premium     Used  $61,998             4.8
# 9376  2017    Buick         Enclave Leather     Used  $26,944             4.8
# 9377  2019   Subaru        Forester Premium     Used  $28,568             4.7
# 9378  2019  Hyundai   Santa Fe Ultimate 2.4     Used  $32,091             4.8
#
# ...

# %%
sales_data['SellerType']
# Out:
# 0       Dealer
# 1       Dealer
# 2       Dealer
# 3       Dealer
# 4       Dealer
#          ...
# 9374    Dealer
# 9375    Dealer
# 9376    Dealer
# 9377    Dealer
# 9378    Dealer
# Name: SellerType, Length: 9379, dtype: object

# %%
data['SellerType'].value_counts()
# Out:
# Dealer     9339
# Private      40
# Name: SellerType, dtype: int64

# %%
Dealer = sales_data.loc[(sales_data['SellerType'] == "Dealer"), ['SellerType','Year','Make','Model','Used/New','Price']]
Dealer
# Out:
#      SellerType  Year     Make                   Model Used/New    Price
# 0        Dealer  2019   Toyota               Sienna SE     Used  $39,998
# 1        Dealer  2018     Ford            F-150 Lariat     Used  $49,985
# 2        Dealer  2017      RAM            1500 Laramie     Used  $41,860
# 3        Dealer  2021    Honda         Accord Sport SE     Used  $28,500
# 4        Dealer  2020    Lexus                  RX 350     Used  $49,000
# ...         ...   ...      ...                     ...      ...      ...
# 9374     Dealer  2019   Subaru  Crosstrek 2.0i Premium     Used  $27,374
# 9375     Dealer  2019     Audi         Q8 3.0T Premium     Used  $61,998
# 9376     Dealer  2017    Buick         Enclave Leather     Used  $26,944
# 9377     Dealer  2019   Subaru        Forester Premium     Used  $28,568
# 9378     Dealer  2019  Hyundai   Santa Fe Ultimate 2.4     Used  $32,091
#
# [9339 rows x 6 columns]

# %%
Dealer = sales_data.loc[(sales_data['SellerType'] == "Private"), ['SellerType','Year','Make','Model','Used/New','Price']]
Dealer
# Out:
#      SellerType  Year           Make  \
# 31      Private  2016          Honda
# 39      Private  2017           Land
# 43      Private  2013       INFINITI
# 45      Private  2017          Tesla
# 56      Private  2017           Land
# 65      Private  2020          Tesla
# 156     Private  2002            BMW
# 231     Private  2021            BMW
# 235     Private  2019  Mercedes-Benz
# 253     Private  2017           Alfa
# 416     Private  2014  Mercedes-Benz
# 432     Private  2021          Mazda
# 436     Private  2014        Lincoln
# 574     Private  2016           Ford
# 583     Private  2021           Jeep
# 812     Private  2019           Ford
# 862     Private  2017            GMC
# 908     Private  2021          Tesla
# 1052    Private  2021          Tesla
# 1288    Private  2014        Hyundai
# 1350    Private  2008      Chevrolet
# 1366    Private  2013           Ford
# 1504    Private  2020          Honda
# 1730    Private  2020            RAM
# ...
