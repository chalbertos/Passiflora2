# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3
from IPython.display import display_html

# %% [markdown]
# # Data Cleaning

# %%
pd.read_csv('Online_Cars_Sale_Marketplace.csv')
# Out:
#       Year     Make                   Model Used/New    Price  ConsumerRating  \
# 0     2019   Toyota               Sienna SE     Used  $39,998             4.6
# 1     2018     Ford            F-150 Lariat     Used  $49,985             4.8
# 2     2017      RAM            1500 Laramie     Used  $41,860             4.7
# 3     2021    Honda         Accord Sport SE     Used  $28,500             5.0
# 4     2020    Lexus                  RX 350     Used  $49,000             4.8
# ...    ...      ...                     ...      ...      ...             ...
# 9374  2019   Subaru  Crosstrek 2.0i Premium     Used  $27,374             4.7
# 9375  2019     Audi         Q8 3.0T Premium     Used  $61,998             4.8
# 9376  2017    Buick         Enclave Leather     Used  $26,944             4.8
# 9377  2019   Subaru        Forester Premium     Used  $28,568             4.7
# 9378  2019  Hyundai   Santa Fe Ultimate 2.4     Used  $32,091             4.8
#
#       ConsumerReviews SellerType  \
# 0                  45     Dealer
# 1                 817     Dealer
# 2                 495     Dealer
# 3                  36     Dealer
# 4                  76     Dealer
# ...               ...        ...
# 9374              205     Dealer
# 9375               27     Dealer
# 9376              137     Dealer
# 9377              279     Dealer
# 9378              204     Dealer
#
#                                              SellerName  SellerRating  ...  \
# 0     CarMax Murrieta - Now offering Curbside Pickup...           3.3  ...
# 1                                       Giant Chevrolet           4.8  ...
# 2                                Gill Auto Group Madera           4.6  ...
# 3                                   AutoSavvy Las Vegas           4.6  ...
# 4                                    Lexus of Henderson           4.8  ...
# ...                                                 ...           ...  ...
# 9374                 Bertera Subaru of West Springfield           4.4  ...
# 9375                           Autobahn USA Westborough           4.8  ...
# 9376                            Tulley Automotive Group           4.7  ...
# 9377                                         Ira Subaru           4.4  ...
# 9378                                   Route 44 Hyundai           4.4  ...
#
#       InteriorColor         Drivetrain MinMPG MaxMPG  FuelType  \
# 0             Black  Front-wheel Drive     19     27  Gasoline
# 1             Black   Four-wheel Drive     19     24  Gasoline
# 2             Black   Four-wheel Drive     15     21  Gasoline
# 3                 –  Front-wheel Drive     29     35  Gasoline
# 4             Birch  Front-wheel Drive     20     27  Gasoline
# ...             ...                ...    ...    ...       ...
# 9374           Gray    All-wheel Drive     27     33  Gasoline
# 9375          Black    All-wheel Drive     17     22    Hybrid
# 9376          Ebony    All-wheel Drive     15     22  Gasoline
# 9377          Black    All-wheel Drive     26     33  Gasoline
# 9378          Black    All-wheel Drive     21     27  Gasoline
#
#             Transmission                             Engine  \
# 0      8-Speed Automatic               3.5L V6 24V PDI DOHC
# 1     10-Speed Automatic    3.5L V6 24V PDI DOHC Twin Turbo
# 2      8-Speed Automatic               5.7L V8 16V MPFI OHV
# 3          Automatic CVT         1.5L I4 16V GDI DOHC Turbo
# 4      8-Speed Automatic               3.5L V6 24V PDI DOHC
# ...                  ...                                ...
# 9374       Automatic CVT               2.0L H4 16V GDI DOHC
# 9375   8-Speed Automatic  3.0L V6 24V GDI DOHC Turbo Hybrid
# 9376   6-Speed Automatic               3.6L V6 24V GDI DOHC
# 9377       Automatic CVT               2.5L H4 16V GDI DOHC
# 9378   8-Speed Automatic               2.4L I4 16V GDI DOHC
#
#                     VIN     Stock#  Mileage
# 0     5TDXZ3DC2KS015402   22998646    29403
# 1     1FTEW1EG2JFD44217     22418A    32929
# 2     1C6RR7VT5HS842283  NG277871G    23173
# 3     1HGCV1F49MA038035      54237    10598
# 4     2T2AZMAA8LC156270   HDT4181A    28137
# ...                 ...        ...      ...
# 9374  JF2GTADC4KH318032    220502A    15606
# 9375  WA1AVAF14KD015389     AB4719    46855
# 9376  5GAKVBKD4HJ190334   B221381B    62649
# 9377  JF2SKAGC9KH423450   KH423450    30760
# 9378  5NMS5CAD1KH002128     H48345    41645
#
# [9379 rows x 32 columns]

# %%
original_frame = pd.read_csv('Online_Cars_Sale_Marketplace.csv')
original_frame.dtypes
# Out:
# Year                       int64
# Make                      object
# Model                     object
# Used/New                  object
# Price                     object
# ConsumerRating           float64
# ConsumerReviews            int64
# SellerType                object
# SellerName                object
# SellerRating             float64
# SellerReviews              int64
# StreetName                object
# State                     object
# Zipcode                   object
# DealType                  object
# ComfortRating            float64
# InteriorDesignRating     float64
# PerformanceRating        float64
# ValueForMoneyRating      float64
# ExteriorStylingRating    float64
# ReliabilityRating        float64
# ExteriorColor             object
# InteriorColor             object
# Drivetrain                object
# MinMPG                     int64
# MaxMPG                     int64
# FuelType                  object
# Transmission              object
# Engine                    object
# VIN                       object
# Stock#                    object
# Mileage                    int64
# dtype: object

# %%
original_frame['DealType'].value_counts()
# Out:
# Good     5524
# Great    2408
# Fair     1225
# Name: DealType, dtype: int64

# %%
#getting rid of c
original_frame.drop(original_frame[original_frame['Price']=='Not Priced'].index, inplace = True)

original_frame['Price']=original_frame['Price'].str.replace(',','')
original_frame['Price']=original_frame['Price'].str.replace('$','')
original_frame['Price']=original_frame['Price'].astype(int)
# Out:
# /var/folders/zr/km3s5d057fq865502skt0rc80000gn/T/ipykernel_65729/2083359120.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   original_frame['Price']=original_frame['Price'].str.replace('$','')

# %%
original_frame['Used/New'] = np.where(original_frame['Used/New'] != 'New', 'Used', original_frame['Used/New'])
original_frame['Used/New'].value_counts()
# Out:
# Used    9374
# Name: Used/New, dtype: int64

# %%
#turning listing prices from objects into integers and turning Used/New column into string format.

# %%
original_frame['Used/New']=original_frame['Used/New'].astype(str)

# %%
original_frame['SellerType']
# Out:
# 0       Dealer
# 1       Dealer
# 2       Dealer
# 3       Dealer
# 4       Dealer
#          ...
# 9374    Dealer
# 9375    Dealer
# 9376    Dealer
# 9377    Dealer
# 9378    Dealer
# Name: SellerType, Length: 9374, dtype: object

# %%
original_frame['Drivetrain']=original_frame['Drivetrain'].astype(str)
original_frame.drop(original_frame[original_frame['Drivetrain']=='-'].index, inplace = True)

# %%
original_frame
# Out:
#       Year     Make                   Model Used/New  Price  ConsumerRating  \
# 0     2019   Toyota               Sienna SE     Used  39998             4.6
# 1     2018     Ford            F-150 Lariat     Used  49985             4.8
# 2     2017      RAM            1500 Laramie     Used  41860             4.7
# 3     2021    Honda         Accord Sport SE     Used  28500             5.0
# 4     2020    Lexus                  RX 350     Used  49000             4.8
# ...    ...      ...                     ...      ...    ...             ...
# 9374  2019   Subaru  Crosstrek 2.0i Premium     Used  27374             4.7
# 9375  2019     Audi         Q8 3.0T Premium     Used  61998             4.8
# 9376  2017    Buick         Enclave Leather     Used  26944             4.8
# 9377  2019   Subaru        Forester Premium     Used  28568             4.7
# 9378  2019  Hyundai   Santa Fe Ultimate 2.4     Used  32091             4.8
#
#       ConsumerReviews SellerType  \
# 0                  45     Dealer
# 1                 817     Dealer
# 2                 495     Dealer
# 3                  36     Dealer
# 4                  76     Dealer
# ...               ...        ...
# 9374              205     Dealer
# 9375               27     Dealer
# 9376              137     Dealer
# 9377              279     Dealer
# 9378              204     Dealer
#
#                                              SellerName  SellerRating  ...  \
# 0     CarMax Murrieta - Now offering Curbside Pickup...           3.3  ...
# 1                                       Giant Chevrolet           4.8  ...
# 2                                Gill Auto Group Madera           4.6  ...
# 3                                   AutoSavvy Las Vegas           4.6  ...
# 4                                    Lexus of Henderson           4.8  ...
# ...                                                 ...           ...  ...
# 9374                 Bertera Subaru of West Springfield           4.4  ...
# 9375                           Autobahn USA Westborough           4.8  ...
# 9376                            Tulley Automotive Group           4.7  ...
# 9377                                         Ira Subaru           4.4  ...
# 9378                                   Route 44 Hyundai           4.4  ...
#
#       InteriorColor         Drivetrain MinMPG MaxMPG  FuelType  \
# 0             Black  Front-wheel Drive     19     27  Gasoline
# 1             Black   Four-wheel Drive     19     24  Gasoline
# 2             Black   Four-wheel Drive     15     21  Gasoline
# 3                 –  Front-wheel Drive     29     35  Gasoline
# 4             Birch  Front-wheel Drive     20     27  Gasoline
# ...             ...                ...    ...    ...       ...
# 9374           Gray    All-wheel Drive     27     33  Gasoline
# 9375          Black    All-wheel Drive     17     22    Hybrid
# 9376          Ebony    All-wheel Drive     15     22  Gasoline
# 9377          Black    All-wheel Drive     26     33  Gasoline
# 9378          Black    All-wheel Drive     21     27  Gasoline
#
#             Transmission                             Engine  \
# 0      8-Speed Automatic               3.5L V6 24V PDI DOHC
# 1     10-Speed Automatic    3.5L V6 24V PDI DOHC Twin Turbo
# 2      8-Speed Automatic               5.7L V8 16V MPFI OHV
# 3          Automatic CVT         1.5L I4 16V GDI DOHC Turbo
# 4      8-Speed Automatic               3.5L V6 24V PDI DOHC
# ...                  ...                                ...
# 9374       Automatic CVT               2.0L H4 16V GDI DOHC
# 9375   8-Speed Automatic  3.0L V6 24V GDI DOHC Turbo Hybrid
# 9376   6-Speed Automatic               3.6L V6 24V GDI DOHC
# 9377       Automatic CVT               2.5L H4 16V GDI DOHC
# 9378   8-Speed Automatic               2.4L I4 16V GDI DOHC
#
#                     VIN     Stock#  Mileage
# 0     5TDXZ3DC2KS015402   22998646    29403
# 1     1FTEW1EG2JFD44217     22418A    32929
# 2     1C6RR7VT5HS842283  NG277871G    23173
# 3     1HGCV1F49MA038035      54237    10598
# 4     2T2AZMAA8LC156270   HDT4181A    28137
# ...                 ...        ...      ...
# 9374  JF2GTADC4KH318032    220502A    15606
# 9375  WA1AVAF14KD015389     AB4719    46855
# 9376  5GAKVBKD4HJ190334   B221381B    62649
# 9377  JF2SKAGC9KH423450   KH423450    30760
# 9378  5NMS5CAD1KH002128     H48345    41645
#
# [9374 rows x 32 columns]

# %% [markdown]
# # Most popular manufacturers

# %%
indexed_by_make = original_frame.set_index(['Make'])
avg_review_score_make = indexed_by_make.groupby(['Make'])['ConsumerRating'].mean()
count_reviews_maker = original_frame.groupby(['Make'])['ConsumerReviews'].sum()
count_reviews_maker
review_and_count = pd.DataFrame({
    'Average Review' : avg_review_score_make,
    'Num of Reviews': count_reviews_maker
})
top_performers = review_and_count[(review_and_count['Average Review']>=4.70) & (review_and_count['Num of Reviews']>= 7500)]
top_performers
# Out:
#          Average Review  Num of Reviews
# Make
# Audi           4.758491           16577
# BMW            4.754083           42044
# Buick          4.714035           13126
# Dodge          4.774483           11575
# Ford           4.722241          142278
# Honda          4.772817          235519
# Hyundai        4.741509           37680
# Jeep           4.740081          117429
# Kia            4.765417           40625
# Lexus          4.762397           29413
# Mazda          4.813171           29426
# Nissan         4.727888           34985
# RAM            4.777931           29513
# Subaru         4.709355           65933
# Toyota         4.745671          191605
# Volvo          4.795946            8541

# %%
# This shows car manufacturers with ratings of =>4.7 and have at least 200 ratings. 
# High average ratings and high # of reviews should be indicative of a popular manufacturer. 
# Plot displays Average Number of Reviews Column.
# Honda has the highest number of consumer reviews and high rating, indicating a popular manufacturer.
# The three most popular manufacturers are Honda, Toyota, and Ford.

# %%
top_performers.plot.bar(
                             y= 'Num of Reviews' ,                             color ='green', 
                             figsize = (7,7),
                            title = 'Car makers with average rating of >=4.7 and >=7500 reviews')
plt.ylim(8000,200000, 1000 )
# Out:
# (8000.0, 200000.0)

# %%
three_makers = ['Toyota', 'Honda', 'Ford']
top_three = original_frame[original_frame['Make'].isin(three_makers)]
top_three.head(10)
# Filtered original datframe for the top three highest rated and most popular car manufacturers.
# Out:
#     Year    Make                      Model Used/New  Price  ConsumerRating  \
# 0   2019  Toyota                  Sienna SE     Used  39998             4.6
# 1   2018    Ford               F-150 Lariat     Used  49985             4.8
# 3   2021   Honda            Accord Sport SE     Used  28500             5.0
# 5   2012  Toyota                4Runner SR5     Used  23541             4.7
# 6   2017   Honda                    HR-V LX     Used  20995             4.6
# 8   2021   Honda  Pilot Touring 8-Passenger     Used  44299             4.8
# 16  2018    Ford               Explorer XLT     Used  32995             4.8
# 18  2018    Ford               Explorer XLT     Used  33341             4.8
# 19  2018    Ford               Explorer XLT     Used  30489             4.8
# 20  2018    Ford               Explorer XLT     Used  32489             4.8
#
#     ConsumerReviews SellerType  \
# 0                45     Dealer
# 1               817     Dealer
# 3                36     Dealer
# 5                34     Dealer
# 6               200     Dealer
# 8                63     Dealer
# 16              265     Dealer
# 18              265     Dealer
# 19              265     Dealer
# 20              265     Dealer
#
#                                            SellerName  SellerRating  ...  \
# 0   CarMax Murrieta - Now offering Curbside Pickup...           3.3  ...
# 1                                     Giant Chevrolet           4.8  ...
# 3                                 AutoSavvy Las Vegas           4.6  ...
# 5                           AutoNation Toyota Hayward           4.4  ...
# 6                   Downtown Toyota-Subaru of Oakland           4.4  ...
# 8                         EchoPark Automotive Phoenix           4.9  ...
# 16                                  Driven Auto Sales           5.0  ...
# 18         Larry H. Miller Used Car Supermarket Sandy           3.9  ...
# 19  EchoPark Automotive Salt Lake City Delivery Ce...           3.0  ...
# 20  EchoPark Automotive Salt Lake City Delivery Ce...           3.0  ...
#
#     InteriorColor         Drivetrain MinMPG MaxMPG  FuelType  \
# 0           Black  Front-wheel Drive     19     27  Gasoline
# 1           Black   Four-wheel Drive     19     24  Gasoline
# 3               –  Front-wheel Drive     29     35  Gasoline
# 5               –   Rear-wheel Drive     17     23  Gasoline
# 6           Black  Front-wheel Drive     28     34  Gasoline
# 8           Beige    All-wheel Drive     19     26  Gasoline
# 16          Black   Four-wheel Drive     16     22  Gasoline
# 18              –   Four-wheel Drive     16     22  Gasoline
# 19    Ebony Black  Front-wheel Drive     17     24  Gasoline
# 20    Ebony Black   Four-wheel Drive     16     22  Gasoline
#
#           Transmission                           Engine                VIN  \
# 0    8-Speed Automatic             3.5L V6 24V PDI DOHC  5TDXZ3DC2KS015402
# 1   10-Speed Automatic  3.5L V6 24V PDI DOHC Twin Turbo  1FTEW1EG2JFD44217
# 3        Automatic CVT       1.5L I4 16V GDI DOHC Turbo  1HGCV1F49MA038035
# 5    5-Speed Automatic            4.0L V6 24V MPFI DOHC  JTEZU5JR3C5043790
# 6        Automatic CVT            1.8L I4 16V MPFI SOHC  3CZRU5H32HG703897
# 8    9-Speed Automatic             3.5L V6 24V GDI SOHC  5FNYF6H90MB052856
# 16   6-Speed Automatic            3.5L V6 24V MPFI DOHC  1FM5K8D89JGB20589
# 18           Automatic   Regular Unleaded V-6 3.5 L/213  1FM5K8D82JGC77140
# 19   6-Speed Automatic       2.3L I4 16V GDI DOHC Turbo  1FM5K7DH7JGC86801
# 20   6-Speed Automatic            3.5L V6 24V MPFI DOHC  1FM5K8D81JGC67795
#
#        Stock#  Mileage
# 0    22998646    29403
# 1      22418A    32929
# 3       54237    10598
# 5    C5043790   105469
# 6       T1480    10458
# 8   YMB052856    14445
# 16      P2214    61294
# 18      R5631    81375
# 19  PJGC86801    28357
# 20  PJGC67795    33188
#
# [10 rows x 32 columns]

# %% [markdown]
# # Most popular car from each of the three most popular manufacturers

# %%
# used exclusively Ratings and Reviews, although there are ratings for performance and comfort etc. 
# Ratings of performance or affordability are not necessarily indicative of popularity. 
Honda = ['Honda']
Honda_data = top_three[top_three['Make'].isin(Honda)]
honda1 =Honda_reviewcount_average = Honda_data.groupby(['Model']).mean()['ConsumerReviews']  
honda2 =Honda_review_average = Honda_data.groupby(['Model']).mean()['ConsumerRating']
honda3 = pd.concat([honda1,honda2], axis = 1)
honda3.sort_values(by = 'ConsumerReviews', ascending = False).head(10)
# Out:
#                   ConsumerReviews  ConsumerRating
# Model
# Civic EX               571.272727        4.800000
# Civic EX-T             546.000000        4.800000
# Accord EX              530.000000        4.766667
# CR-V EX-L              497.513228        4.804233
# CR-V Touring           486.238095        4.761905
# Accord EX-L 2.0T       485.000000        4.800000
# Accord LX              482.333333        4.766667
# CR-V LX                475.764706        4.800000
# CR-V EX                475.025974        4.801299
# Accord EX-L 1.5T       437.500000        4.750000

# %%
# Having the highest # of reviews and the highest average review of the highest number of reviews column; 
# Honda Civic Ex wth an average of 571 reviews and 4.8/5 average ratings.

# %%
Ford = ['Ford']
Ford_data = top_three[top_three['Make'].isin(Ford)]
Ford1 =Ford_reviewcount_average = Ford_data.groupby(['Model']).mean()['ConsumerReviews']  
Ford2 =Ford_review_average = Ford_data.groupby(['Model']).mean()['ConsumerRating']
Ford3 = pd.concat([Ford1,Ford2], axis = 1)
Ford3.sort_values(by = 'ConsumerReviews', ascending = False).head(10)
# Out:
#                   ConsumerReviews  ConsumerRating
# Model
# Escape S               547.750000        4.625000
# Escape SE              502.857143        4.695238
# F-150 XL               499.428571        4.800000
# F-150 Raptor           490.333333        4.800000
# F-150 King Ranch       430.750000        4.725000
# F-150 Platinum         399.000000        4.785714
# F-150                  391.000000        4.600000
# F-150 Lariat           387.553571        4.785714
# Escape Titanium        381.113636        4.647727
# F-150 XLT              376.621622        4.775676

# %%
# The Fod 150 XL seems to be the most popoular Ford Model
# given it has average number of 500 ratings and  4.8/5 average reviews.

# %%
Ford = ['Ford']
Ford_data = top_three[top_three['Make'].isin(Ford)]
Ford1 =Ford_reviewcount_average = Ford_data.groupby(['Model']).mean()['ConsumerReviews']  
Ford2 =Ford_review_average = Ford_data.groupby(['Model']).mean()['ConsumerRating']
Ford3 = pd.concat([Ford1,Ford2], axis = 1)
Ford3.sort_values(by = 'ConsumerReviews', ascending = False).head(10)
# Out:
#                   ConsumerReviews  ConsumerRating
# Model
# Escape S               547.750000        4.625000
# Escape SE              502.857143        4.695238
# F-150 XL               499.428571        4.800000
# F-150 Raptor           490.333333        4.800000
# F-150 King Ranch       430.750000        4.725000
# F-150 Platinum         399.000000        4.785714
# F-150                  391.000000        4.600000
# F-150 Lariat           387.553571        4.785714
# Escape Titanium        381.113636        4.647727
# F-150 XLT              376.621622        4.775676

# %%
# The Toyota Camry XLE seems to be the most popoular Toyota Model with an avrage 545 reviews and average 4.75/5 
Toyota = ['Toyota']
Toyota_data = top_three[top_three['Make'].isin(Toyota)]
Toyota1 =Toyota_reviewcount_average = Toyota_data.groupby(['Model']).mean()['ConsumerReviews']  
Toyota2 =Toyota_review_average = Toyota_data.groupby(['Model']).mean()['ConsumerRating']
Toyota3 = pd.concat([Toyota1,Toyota2], axis = 1)
Toyota3.sort_values(by = 'ConsumerReviews', ascending = False).head(10)
# Out:
#                              ConsumerReviews  ConsumerRating
# Model
# RAV4 Limited                      549.419355        4.709677
# Camry XLE                         545.000000        4.750000
# RAV4 XLE                          520.309859        4.750704
# RAV4 LE                           398.723214        4.738393
# Highlander LE Plus                363.000000        4.600000
# RAV4 Sport                        351.333333        4.533333
# Highlander LE                     330.285714        4.700000
# Highlander SE                     301.000000        4.625000
# Highlander Limited                291.583333        4.754167
# Highlander Limited Platinum       273.500000        4.700000

# %%
top_three = ['Camry XLE', 'Civic EX', 'F-150 XL']
top_three_frame = original_frame[original_frame['Model'].isin(top_three)]
top_three_filtered = top_three_frame[['Year',
                                      'Used/New',
                                      'Make',
                                      'Model',
                                      'Used/New',
                                      'Price',
                                      'ConsumerRating',
                                      'ConsumerReviews',
                                      'SellerType',
                                      'Mileage',
                                     'ReliabilityRating',
                                     'ValueForMoneyRating',
                                     'PerformanceRating',
                                     'MaxMPG']]
top_three_filtered
# Out:
#       Year Used/New    Make      Model Used/New  Price  ConsumerRating  \
# 44    2017     Used   Honda   Civic EX     Used  22004             4.8
# 51    2018     Used   Honda   Civic EX     Used  23739             4.8
# 365   2018     Used    Ford   F-150 XL     Used  34999             4.8
# 1572  2017     Used    Ford   F-150 XL     Used  21995             4.8
# 2152  2017     Used    Ford   F-150 XL     Used  31300             4.8
# 3051  2017     Used   Honda   Civic EX     Used  19995             4.8
# 3301  2019     Used   Honda   Civic EX     Used  29100             4.9
# 4018  2018     Used    Ford   F-150 XL     Used  28989             4.8
# 4227  2017     Used   Honda   Civic EX     Used  20932             4.8
# 4828  2018     Used  Toyota  Camry XLE     Used  28541             4.7
# 4864  2017     Used   Honda   Civic EX     Used  22997             4.8
# 5355  2018     Used   Honda   Civic EX     Used  34649             4.8
# 5588  2018     Used   Honda   Civic EX     Used  24471             4.8
# 5743  2019     Used  Toyota  Camry XLE     Used  33900             4.8
# 6124  2018     Used   Honda   Civic EX     Used  27687             4.8
# 6365  2017     Used    Ford   F-150 XL     Used  21995             4.8
# 6679  2021     Used    Ford   F-150 XL     Used  49090             4.8
# 7466  2015     Used   Honda   Civic EX     Used  18000             4.7
# 8926  2021     Used    Ford   F-150 XL     Used  46287             4.8
# 9260  2018     Used   Honda   Civic EX     Used  23289             4.8
#
#       ConsumerReviews SellerType  Mileage  ReliabilityRating  \
# 44                743     Dealer    35257                4.8
# 51                546     Dealer    32333                4.8
# 365               817     Dealer    51960                4.7
# 1572              568     Dealer    87552                4.8
# 2152              568     Dealer    38495                4.8
# 3051              743     Dealer   102164                4.8
# 3301              275     Dealer     7869                4.9
# 4018              817     Dealer    49624                4.7
# 4227              743     Dealer    68879                4.8
# 4828              781     Dealer    16740                4.8
# 4864              743     Dealer    17941                4.8
# 5355              546     Dealer    46751                4.8
# 5588              546     Dealer    12150                4.8
# 5743              309     Dealer    10200                4.8
# 6124              546     Dealer    32125                4.8
# 6365              568     Dealer    87552                4.8
# 6679               79     Dealer    15762                4.7
# 7466              307     Dealer    87416                4.8
# 8926               79     Dealer    19339                4.7
# 9260              546     Dealer    46826                4.8
#
#       ValueForMoneyRating  PerformanceRating  MaxMPG
# 44                    4.8                4.8      40
# 51                    4.8                4.8      40
# 365                   4.6                4.8      23
# 1572                  4.6                4.8      23
# 2152                  4.6                4.8      23
# 3051                  4.8                4.8      40
# 3301                  4.8                4.9      40
# 4018                  4.6                4.8      25
# 4227                  4.8                4.8      40
# 4828                  4.6                4.6      39
# 4864                  4.8                4.8      40
# 5355                  4.8                4.8      40
# 5588                  4.8                4.8      40
# 5743                  4.6                4.7      39
# 6124                  4.8                4.8      40
# 6365                  4.6                4.8      23
# 6679                  4.6                4.8      22
# 7466                  4.7                4.6      39
# 8926                  4.6                4.8      22
# 9260                  4.8                4.8      40

# %%
 #Accord Median Price per SellerType
Civic = (top_three_filtered[(original_frame['Model']=='Civic EX')])
F150 = (top_three_filtered[(original_frame['Model']=='F-150 XL')])
Camry = (top_three_filtered[(original_frame['Model']=='Camry XLE')])
Camry
# Out:
# /var/folders/zr/km3s5d057fq865502skt0rc80000gn/T/ipykernel_65729/2611443192.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Civic = (top_three_filtered[(original_frame['Model']=='Civic EX')])
# /var/folders/zr/km3s5d057fq865502skt0rc80000gn/T/ipykernel_65729/2611443192.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   F150 = (top_three_filtered[(original_frame['Model']=='F-150 XL')])
# /var/folders/zr/km3s5d057fq865502skt0rc80000gn/T/ipykernel_65729/2611443192.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Camry = (top_three_filtered[(original_frame['Model']=='Camry XLE')])
#       Year Used/New    Make      Model Used/New  Price  ConsumerRating  \
# 4828  2018     Used  Toyota  Camry XLE     Used  28541             4.7
# 5743  2019     Used  Toyota  Camry XLE     Used  33900             4.8
#
#       ConsumerReviews SellerType  Mileage  ReliabilityRating  \
# 4828              781     Dealer    16740                4.8
# 5743              309     Dealer    10200                4.8
#
#       ValueForMoneyRating  PerformanceRating  MaxMPG
# 4828                  4.6                4.6      39
# 5743                  4.6                4.7      39

# %%
F150.groupby(['Year']).mean()
# based on the highest average # of reviews and highest average review, the 2018
# Out:
#              Price  ConsumerRating  ConsumerReviews       Mileage  \
# Year
# 2017  25096.666667             4.8            568.0  71199.666667
# 2018  31994.000000             4.8            817.0  50792.000000
# 2021  47688.500000             4.8             79.0  17550.500000
#
#       ReliabilityRating  ValueForMoneyRating  PerformanceRating  MaxMPG
# Year
# 2017                4.8                  4.6                4.8    23.0
# 2018                4.7                  4.6                4.8    24.0
# 2021                4.7                  4.6                4.8    22.0

# %%
Camry.groupby(['Year']).mean()
# Based on average years and reviews the 2018 Camry XLE is the most popular Camry model.
# Out:
#         Price  ConsumerRating  ConsumerReviews  Mileage  ReliabilityRating  \
# Year
# 2018  28541.0             4.7            781.0  16740.0                4.8
# 2019  33900.0             4.8            309.0  10200.0                4.8
#
#       ValueForMoneyRating  PerformanceRating  MaxMPG
# Year
# 2018                  4.6                4.6    39.0
# 2019                  4.6                4.7    39.0

# %%
original_frame['SellerType'].value_counts()

# %%
Civic.groupby(['Year']).mean()
#based on average # of reviews and high avergae review, the 2017 Honda Civic is the most popular.
# Out:
#         Price  ConsumerRating  ConsumerReviews   Mileage  ReliabilityRating  \
# Year
# 2015  18000.0             4.7            307.0  87416.00                4.8
# 2017  21482.0             4.8            743.0  56060.25                4.8
# 2018  26767.0             4.8            546.0  34037.00                4.8
# 2019  29100.0             4.9            275.0   7869.00                4.9
#
#       ValueForMoneyRating  PerformanceRating  MaxMPG
# Year
# 2015                  4.7                4.6    39.0
# 2017                  4.8                4.8    40.0
# 2018                  4.8                4.8    40.0
# 2019                  4.8                4.9    40.0
